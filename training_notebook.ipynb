# %%
# Define the YAML content
yaml_content = """
train: /kaggle/input/finalt/T/T9/images/train
val: /kaggle/input/finalt/T/T9/images/train

# Number of classes
nc: 8

names:
  0: person
  1: bicycle
  2: car
  3: motorcycle
  4: airplane
  5: bus
  6: train
  7: truck
"""

# Write the content to a data.yaml file
with open('data.yaml', 'w') as file:
    file.write(yaml_content)

# Confirm the file creation
print("data.yaml created successfully.")
# Out:
# data.yaml created successfully.

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 877.6/877.6 kB 15.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !yolo settings wandb=False
# Out:
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/kaggle/working/datasets",
#   "weights_dir": "weights",
#   "runs_dir": "runs",
#   "uuid": "1bfc3e992d24318da58ddee183be5bf9388a31f26bab1738e986ec4d297417ff",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": false,
#   "vscode_msg": true
# }
# 💡 Learn more about Ultralytics Settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/kaggle/input/finalyaml/yum.yaml epochs=30 save_period=5
# Out:
# ...
# 100%|███████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 146MB/s]
# Ultralytics 8.3.22 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val data=/kaggle/input/finalyaml/yum.yaml
# Out:
# Ultralytics 8.3.22 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: Scanning /kaggle/input/finalt/T/T1/labels/train... 14422 images, 0 backgrou
# val: WARNING ⚠️ Cache directory /kaggle/input/finalt/T/T1/labels is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      14422      68768      0.694      0.502       0.56      0.395
#                 person      12809      52346      0.774      0.652      0.731      0.512
#                bicycle        644       1390      0.581      0.274      0.298      0.184
#                    car       2429       8542      0.663      0.378      0.438      0.276
#             motorcycle        746       1709      0.686      0.435       0.49      0.302
#               airplane        342        722      0.794      0.573      0.656      0.442
# ...

# %%
# !yolo task=detect mode=train model=/kaggle/input/after_bigt1/pytorch/default/1/bigT1.pt data=/kaggle/input/bigfort3/yum.yaml epochs=30 save_period=5
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model=/kaggle/working/runs/detect/train/weights/last.pt data=/kaggle/working/data.yaml
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /kaggle/input/finalt/T/T5/labels/train... 14422 images, 0 backgrou
# val: WARNING ⚠️ Cache directory /kaggle/input/finalt/T/T5/labels is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      14422      69748      0.767      0.639      0.711      0.556
#                 person      12780      52527       0.83      0.642      0.756       0.52
#                bicycle        638       1425      0.717      0.533      0.582      0.436
#                    car       2486       9018       0.78      0.615      0.681      0.482
#             motorcycle        706       1806      0.794      0.656      0.738      0.563
#               airplane        339        755      0.795      0.687      0.753      0.587
# ...

# %%
# !yolo task=detect mode=val data=/kaggle/working/data.yaml
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: Scanning /kaggle/input/finalt/T/T5/labels/train... 14422 images, 0 backgrou
# val: WARNING ⚠️ Cache directory /kaggle/input/finalt/T/T5/labels is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      14422      69748      0.697      0.479      0.545      0.386
#                 person      12780      52527      0.788      0.651      0.735      0.516
#                bicycle        638       1425      0.588      0.276      0.305      0.186
#                    car       2486       9018      0.651      0.361      0.422       0.26
#             motorcycle        706       1806      0.656      0.362      0.419      0.254
#               airplane        339        755      0.783      0.519      0.626      0.433
# ...

# %%
# !yolo task=detect mode=train model=/kaggle/input/afterbigt3/tensorflow2/default/1/bigT3.pt data=/kaggle/working/data.yaml epochs=30 save_period=5
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val model=/kaggle/input/afterbigt5/tensorflow2/default/1/last.pt data=/kaggle/working/data.yaml
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /kaggle/input/finalt/T/T7/labels/train... 14422 images, 0 backgrou
# val: WARNING ⚠️ Cache directory /kaggle/input/finalt/T/T7/labels is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      14422      69724      0.771      0.637      0.713      0.559
#                 person      12900      53160      0.836      0.644      0.762      0.527
#                bicycle        629       1369      0.721      0.514       0.58      0.435
#                    car       2420       8652      0.804      0.598      0.685      0.487
#             motorcycle        689       1785      0.793      0.668      0.743      0.561
#               airplane        355        756      0.801        0.7      0.766      0.594
# ...

# %%
# !yolo task=detect mode=val data=/kaggle/working/data.yaml
# Out:
# ...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 64.6MB/s]
# Ultralytics 8.3.23 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: Scanning /kaggle/input/finalt/T/T7/labels/train... 14422 images, 0 backgrou
# val: WARNING ⚠️ Cache directory /kaggle/input/finalt/T/T7/labels is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      14422      69724      0.686      0.487      0.547      0.386
#                 person      12900      53160      0.779      0.658      0.737      0.517
#                bicycle        629       1369      0.576      0.252      0.275      0.166
#                    car       2420       8652       0.66      0.359      0.422      0.263
#             motorcycle        689       1785      0.649      0.432      0.481       0.29
# ...

# %%
# !yolo task=detect mode=train data=/kaggle/working/data.yaml model=/kaggle/input/afterbigt5/tensorflow2/default/1/last.pt epochs=30 save_period=5
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=val data=/kaggle/input/bigfort3/yum.yaml
# Out:
# ...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 64.8MB/s]
# Ultralytics 8.3.23 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# ...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 13.7MB/s]
# val: Scanning /kaggle/input/finalt/T/T3/labels/train... 14422 images, 0 backgrou
# val: WARNING ⚠️ Cache directory /kaggle/input/finalt/T/T3/labels is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      14422      68908      0.703      0.484      0.549      0.389
#                 person      12793      52086      0.782      0.647       0.73      0.513
#                bicycle        695       1477      0.609      0.272      0.306      0.193
#                    car       2475       8707      0.666      0.372      0.435       0.27
# ...

# %%
# !yolo task=detect mode=val data=/kaggle/input/bigfort3/yum.yaml model=/kaggle/input/afterbigt7/tensorflow2/default/1/bigT7.pt
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /kaggle/input/finalt/T/T3/labels/train... 14422 images, 0 backgrou
# val: WARNING ⚠️ Cache directory /kaggle/input/finalt/T/T3/labels is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all      14422      68908      0.798      0.665      0.749      0.597
#                 person      12793      52086      0.844      0.652      0.772      0.545
#                bicycle        695       1477      0.774      0.542      0.643      0.487
#                    car       2475       8707      0.805      0.634      0.716      0.512
#             motorcycle        676       1658      0.808       0.68      0.754      0.587
#               airplane        361        806      0.843      0.715      0.795      0.641
# ...

# %%
# !yolo task=detect mode=train data=/kaggle/input/bigfort3/yum.yaml model=/kaggle/input/afterbigt7/tensorflow2/default/1/bigT7.pt save_period=5 epochs=30
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...
